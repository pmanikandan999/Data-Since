# %%
import pandas as pd

# %%
dataset=pd.read_csv("PrePlacement.csv")

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
#!pip install seaborn

# %%
import seaborn as sns

# %%
sns.distplot(dataset["ssc_p"])
# Out:
# C:\Users\Manikandan\anaconda3\envs\aiml\lib\site-packages\ipykernel_launcher.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """Entry point for launching an IPython kernel.
# <AxesSubplot:xlabel='ssc_p', ylabel='Density'>

# %%
def get_pdf_probability(dataset,startrange,endrange):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
    pyplot.axvline(startrange,color='Red')
    pyplot.axvline(endrange,color='Red')
    # generate a sample
    sample = dataset
    # calculate parameters
    sample_mean =sample.mean()
    sample_std = sample.std()
    print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))
    # define the distribution
    dist = norm(sample_mean, sample_std)
    
    # sample probabilities for a range of outcomes
    values = [value for value in range(startrange, endrange)]
    probabilities = [dist.pdf(value) for value in values]    
    prob=sum(probabilities)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %%
get_pdf_probability(dataset["ssc_p"],60,70)
# Out:
# Mean=67.303, Standard Deviation=10.827
# The area between range(60,70):0.3449514151280293
# C:\Users\Manikandan\anaconda3\envs\aiml\lib\site-packages\ipykernel_launcher.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """
# 0.3449514151280293

# %%
#!pip install statsmodels
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.13.5-cp37-cp37m-win_amd64.whl (9.1 MB)
#      ---------------------------------------- 9.1/9.1 MB 385.5 kB/s eta 0:00:00
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
#      -------------------------------------- 233.9/233.9 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.3 in c:\users\manikandan\anaconda3\envs\aiml\lib\site-packages (from statsmodels) (1.7.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\manikandan\anaconda3\envs\aiml\lib\site-packages (from statsmodels) (1.3.5)
# Requirement already satisfied: packaging>=21.3 in c:\users\manikandan\anaconda3\envs\aiml\lib\site-packages (from statsmodels) (23.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\manikandan\anaconda3\envs\aiml\lib\site-packages (from statsmodels) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\manikandan\anaconda3\envs\aiml\lib\site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\manikandan\anaconda3\envs\aiml\lib\site-packages (from pandas>=0.25->statsmodels) (2023.3.post1)
# Requirement already satisfied: six in c:\users\manikandan\anaconda3\envs\aiml\lib\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-0.5.6 statsmodels-0.13.5

# %%
from statsmodels.distributions.empirical_distribution import ECDF
ecdf = ECDF(dataset['ssc_p'])
ecdf(78)
# Out:
# 0.827906976744186

# %%
def stdndgraph(dataset):
        # Coverted to standard Normal Distribution
    import seaborn as sns
    mean=dataset.mean()
    std=dataset.std()

    values=[i for i in dataset]

    z_score=[((j-mean)/std) for j in values]

    sns.distplot(z_score,kde=True)

    sum(z_score)/len(z_score)
    #z_score.std()

# %%
stdndgraph(dataset["ssc_p"])
# Out:
# C:\Users\Manikandan\anaconda3\envs\aiml\lib\site-packages\ipykernel_launcher.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   # This is added back by InteractiveShellApp.init_path()
